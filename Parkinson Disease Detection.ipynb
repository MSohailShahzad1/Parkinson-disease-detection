# %% [markdown]
# # **Startup**

# %% [markdown]
# Mounting google drive

# %% [markdown]
# Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading CSV file

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/Parkinsson disease.csv')

# %% [markdown]
# Loading The Dataset

# %%
data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# Shape of the data

# %%
data.shape
# Out:
# (195, 24)

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# Getting Basic Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %% [markdown]
# Check for Missing Values

# %%
data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# Check for Duplicate Values

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Drop name

# %%
data = data.drop('name', axis=1)

# %% [markdown]
# Count Of the Target Variable

# %%
data['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %% [markdown]
# # **Dataset Visualization**

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Features')
plt.show()

# %%
for column in data.columns[:-1]:  # Exclude the 'status' column
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='status', y=column, data=data)
    plt.title(f'Box Plot of {column} by Status')
    plt.show()

# %%
for column in data.columns[:-1]:  # Exclude the 'status' column
    plt.figure(figsize=(8,6))
    sns.histplot(data[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
selected_features = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)', 'status']
sns.pairplot(data[selected_features], hue='status')
plt.show()

# %% [markdown]
# # **Resampling : Visualizing the target variable**

# %%
sns.countplot(x='status', data=data, palette='viridis', hue='status')
plt.title('Target feature Distribution')
# Out:
# Text(0.5, 1.0, 'Target feature Distribution')

# %% [markdown]
# Resampling data using Over Sample

# %%
# !pip install --upgrade --force-reinstall scikit-learn
# !pip install --upgrade imbalanced-learn
# Out:
# ...
#   Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# ...
#   Using cached numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#   Using cached scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)

# %%
from imblearn.over_sampling import SMOTE

# Separate features and target variable
X = data.drop('status', axis=1)
y = data['status']

# Apply SMOTE to oversample the minority class
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Create a new balanced DataFrame
balanced_data = pd.DataFrame(X_resampled, columns=X.columns)
balanced_data['status'] = y_resampled
data = balanced_data
# Visualize the balanced target variable
sns.countplot(x='status', data = data, palette='viridis', hue='status')
plt.title('Balanced Target Feature Distribution')
plt.show()

# %%
data['status'].value_counts()

# %% [markdown]
# # **Feature Engeerinig**

# %% [markdown]
# Separate Features and Target

# %%
X = data.drop(columns=['status'])
y = data['status']

# %% [markdown]
# Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaledx = scaler.fit_transform(X)

# %% [markdown]
# Selecting important features

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.95)
pcaX = pca.fit_transform(scaledx)
pcaX_df = pd.DataFrame(pcaX)

# %% [markdown]
# # **Data splitting for training and testing**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(pcaX_df, y, test_size=0.2, random_state=11)
# print the shape of train and test data
print("X_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)
print("X_test shape: ", X_test.shape)
print("y_test shape: ", y_test.shape)

# %% [markdown]
# # **k-Nearest Neighbors (k-NN)**

# %% [markdown]
# Importing Library and creating KNN object

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Training the model

# %%
knn.fit(X_train, y_train)

# %% [markdown]
# Making Prediction on testing data

# %%
y_pred = knn.predict(X_test)
y_pred[0:10]

# %% [markdown]
# As this is a Classification type algorithm. So, using confusion matrix to display it

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=["Not Parkinson", "Parkinson"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Now checking the effeciency of model using performance matrices

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)


print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

# %% [markdown]
# # **LOGISTIC REGRESSION**

# %% [markdown]
# Importing Library and creating logistic regression object

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %% [markdown]
# training the model

# %%
lr.fit(X_train, y_train)

# %% [markdown]
# Making preidction on model

# %%
y_pred_lr = lr.predict(X_test)

# %% [markdown]
# making confusion matrix

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_lr), display_labels=["Not Parkinson", "Parkinson"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")

# %% [markdown]
# **Performance measuring**

# %%
accuracy = accuracy_score(y_test, y_pred_lr)
precision = precision_score(y_test, y_pred_lr)
recall = recall_score(y_test, y_pred_lr)
f1 = f1_score(y_test, y_pred_lr)

# %% [markdown]
# **Printing the result**

# %%
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

# %% [markdown]
# # **Naive bayes Algorithm**

# %% [markdown]
# **Import the necessary library and creating object**

# %%
from sklearn.naive_bayes import GaussianNB
nb_classifier = GaussianNB()

# %% [markdown]
# **Training the model**

# %%
nb_classifier.fit(X_train, y_train)

# %% [markdown]
# **Making Prediction**

# %%
y_pred = nb_classifier.predict(X_test)

# %% [markdown]
# **Confusion Matrix**

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_lr), display_labels=["Not Parkinson", "Parkinson"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")

# %% [markdown]
# **`Performance Measurement`**

# %%
accuracy = accuracy_score(y_test, y_pred_lr)
precision = precision_score(y_test, y_pred_lr)
recall = recall_score(y_test, y_pred_lr)
f1 = f1_score(y_test, y_pred_lr)

# %% [markdown]
# **Printing the Score**

# %%
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

# %% [markdown]
# # **Decision tree Algorithm**

# %% [markdown]
# Import the necessary library and creating object

# %%
from sklearn.tree import DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# %% [markdown]
# Training the model

# %%
dt_classifier.fit(X_train, y_train)

# %% [markdown]
# Making Prediction

# %%
y_pred = dt_classifier.predict(X_test)

# %% [markdown]
# Confusion matrix

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_lr), display_labels=["Not Parkinson", "Parkinson"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")

# %% [markdown]
# Performance measurement

# %%
accuracy = accuracy_score(y_test, y_pred_lr)
precision = precision_score(y_test, y_pred_lr)
recall = recall_score(y_test, y_pred_lr)
f1 = f1_score(y_test, y_pred_lr)

# %% [markdown]
# Printing them

# %%
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

# %% [markdown]
# # **Ensemble Learning**

# %% [markdown]
# importing necessary library

# %%
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# creating individual classifier

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=3)
lr_classifier = LogisticRegression()
nb_classifier = GaussianNB()
dt_classifier = DecisionTreeClassifier(random_state=42)

# %% [markdown]
# creating a voting classifier Voting **HARD**

# %%
estimators = [('knn', knn_classifier), ('lr', lr_classifier), ('nb', nb_classifier), ('dt', dt_classifier)]
ensemble_classifier = VotingClassifier(estimators=estimators, voting='hard')

# %% [markdown]
# Training the model

# %%
ensemble_classifier.fit(X_train, y_train)

# %% [markdown]
# Predicting the model

# %%
y_pred = ensemble_classifier.predict(X_test)

# %% [markdown]
# Evaluating the model

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)


print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# creating a voting classifier Voting **SOFT**

# %%
estimators = [('knn', knn_classifier), ('lr', lr_classifier), ('nb', nb_classifier), ('dt', dt_classifier)]
ensemble_classifier = VotingClassifier(estimators=estimators, voting='soft')

# %% [markdown]
# Training the Model

# %%
ensemble_classifier.fit(X_train, y_train)

# %% [markdown]
# Predicting the Model

# %%
y_pred = ensemble_classifier.predict(X_test)

# %% [markdown]
# Evaluating Model

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)


print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

# %% [markdown]
# # **Ensemble Learning Boosting**

# %%
import xgboost as xgb

# %%
# Create an XGBoost classifier
xgb_classifier = xgb.XGBClassifier(
    n_estimators=100,  # Number of boosting rounds
    learning_rate=0.1,  # Step size shrinkage used in update to prevents overfitting
    max_depth=3,  # Maximum depth of a tree
    objective='binary:logistic',  # Specify the learning task and the corresponding learning objective
    random_state=42,  # For reproducibility
)

# %%
# Train the XGBoost classifier
xgb_classifier.fit(X_train, y_train)

# %%
# Make predictions on the test set
y_pred_xgb = xgb_classifier.predict(X_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred_xgb)
precision = precision_score(y_test, y_pred_xgb)
recall = recall_score(y_test, y_pred_xgb)
f1 = f1_score(y_test, y_pred_xgb)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

# %% [markdown]
# # **Ensemble Learning Stacking**

# %%
from sklearn.ensemble import StackingClassifier

# %%
base_learners = [
    ('knn', KNeighborsClassifier(n_neighbors=3)),
    ('lr', LogisticRegression()),
    ('nb', GaussianNB()),
    ('dt', DecisionTreeClassifier(random_state=42)),
]

meta_learner = LogisticRegression()

stacking_classifier = StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_learner,
    cv=5,
    stack_method='predict_proba',
)

# %%
stacking_classifier.fit(X_train, y_train)

# %%
y_pred_stacking = stacking_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_stacking)
precision = precision_score(y_test, y_pred_stacking)
recall = recall_score(y_test, y_pred_stacking)
f1 = f1_score(y_test, y_pred_stacking)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

# %% [markdown]
# # **SVM**

# %%
from sklearn.svm import SVC

# %%
svm_classifier = SVC(kernel='linear')

# %%
svm_classifier.fit(X_train, y_train)

# %%
y_pred_svm = svm_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_stacking)
precision = precision_score(y_test, y_pred_stacking)
recall = recall_score(y_test, y_pred_stacking)
f1 = f1_score(y_test, y_pred_stacking)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
